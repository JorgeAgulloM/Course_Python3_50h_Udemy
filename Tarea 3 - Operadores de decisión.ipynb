# %% [markdown]
# Ejercicio 1
#
# Haz que un usuario introduzca un número real y evalúa si dicho número es positivo, negativo o cero. Devuelve
# por pantalla el resultado en cada caso.

# %%
numb = int(input("Intoduce un número: "))
if numb > 0:
    print("El número {} es positivo".format(numb))
elif numb == 0:
    print("El número {} es cero".format(numb))
elif numb < 0:
    print("El número {} es negativo".format(numb))
# Out:
# Intoduce un número: -2351616
# El número -2351616 es negativo

# %% [markdown]
# Ejercicio 2
#
# Haz que un usuario introduzca su nombre y evalúa con operadores if y else si dicho nombre tiene una
# longitud mayor a 10 caracteres o no. Devuelve por pantalla el resultado en cada caso.

# %%
name = input("Introduce tu nombre: ")
si = "Tu nombre ({}) tiene diez o más caracteres".format(name)
no = "Tu nombre ({}) no tiene diez o más caracteres".format(name)
if len(name) >= 10:
    print(si)
else:
    print(no)
# Out:
# Introduce tu nombre: Jose Gabriel
# Tu nombre (Jose Gabriel) tiene diez o más caracteres

# %% [markdown]
# Ejercicio 3
#
# Realiza el ejercicio anterior con el uso del operador ternario.

# %%
name = input("Introduce tu nombre: ")
si = "Tu nombre ({}) tiene diez o más caracteres".format(name)
no = "Tu nombre ({}) no tiene diez o más caracteres".format(name)
print(si) if len(name) >= 10 else print(no)

# %% [markdown]
# Ejercicio 4
#
# Haz que un usuario introduzca dos números enteros positivos. Comprueba si el primer número introducido
# por el usuario es mayor o igual que el segundo número introducido por el usuario. Devuelve por pantalla el
# resultado en cada caso.
# PISTA: Asegúrate de hacer uso de la función int() donde pertoque.

# %%
print("Introduce dos números enteros por favor")
numb1 = int(input("Número 1: "))
numb2 = int(input("Número 2: "))

if numb1 >= numb2:
    if numb1 == numb2:
        print("El primer número ({}) es igual que el segundo ({})".format(numb1, numb2))
    else:
        print("El primer número ({}) es mayor que el segundo ({})".format(numb1, numb2))
else:
    print("El primer número ({}) es menor que el segundo ({})".format(numb1, numb2))
# Out:
# Introduce dos números enteros positivos por favor
# Número 1: 34
# Número 2: 50
# El primer número (34) es menor que el segundo (50)

# %% [markdown]
# Ejercicio 5
#
# Haz que un usuario introduzca dos números enteros positivos. Suponiendo que el primer número introducido
# por el usuario es mayor o igual al segundo número introducido por el usuario, comprueba que la división del
# primer número entre el segundo número es entera.
# En caso de la división ser entera, devuelve el cociente por pantalla e indica que la división en efecto es entera.
# En caso de la división no ser entera, devuelve el cociente y el resto por pantalla e indica que la división entre
# los dos números no es entera

# %%
print("Introduce dos números enteros positivos por favor")
numb1 = int(input("Número 1: "))
numb2 = int(input("Número 2: "))

if numb1 > 0 and numb2 > 0:
    if numb1 >= numb2:
        if numb1 % numb2 == 0:
            print("La división {}/{} es entera y resulta igual a: ".format(numb1, numb2), (numb1/numb2))
        else:
             print("La división {}/{} no es entera y se obtiene un coiente de: ".format(numb1, numb2), (numb1 / numb2), "\ny un resto de: ", (numb1 % numb2))
    else:
        print("El primer número introducido ({}) no es mayor o igual que el segundo ({}), por lo que no se puede realizar la operación".format(numb1, numb2))
# Out:
# Introduce dos números enteros positivos por favor
# Número 1: 10
# Número 2: 20
# El primer número introducido (10) no es mayor que el segundo (20), por lo que no se puede realizar la operación

# %% [markdown]
# Ejercicio 6
#
# Fusiona lo hecho en los ejercicios 4 y 5 para que
# 1. Un usuario introduzca dos números enteros por pantalla.
# 2. Comprobar si el primer número es mayor o igual al segundo número introducido por el usuario. Devolver
# por pantalla en que caso nos encontramos.
# 3. Hacer la división entera pertinente en cada caso.
# 4. Si la división es entera, entonces devolver por pantalla el cociente e indicar que la división es entera.
# Si la división no es entera, entonces devolver por pantalla el cociente y el resto e indicar que la división
# realizada no es entera.

# %%
print("Introduce dos números enteros por favor")
numb1 = int(input("Número 1: "))
numb2 = int(input("Número 2: "))
integer = False

if numb1 >= numb2:
    integer = True

if integer:
    print("El primer número ({}) es mayor que el segundo ({})".format(numb1, numb2))
else:
    print("El primer número ({}) es menor que el segundo ({})".format(numb1, numb2))

if numb1 % numb2 == 0:
    print("La división {}/{} es entera y resulta igual a: ".format(numb1, numb2), (numb1/numb2))
else:
    print("La división {}/{} no es entera y se obtiene un coiente de: ".format(numb1, numb2), (numb1 / numb2), "\ny un resto de: ", (numb1 % numb2))
# Out:
# Introduce dos números enteros positivos por favor
# Número 1: 10
# Número 2: 20
# El primer número (10) es menor que el segundo (20)
# La división {}/{} no es entera y se obtiene un coiente de:  0.5
# y un resto de:  10

# %% [markdown]
# Ejercicio 7
#
# Haz que un usuario introduzca dos números enteros positivos. Comprueba si el mayor es múltiplo del menor.
# Devuelve por pantalla el resultado en cada caso.

# %%
print("Introduce dos números enteros positivos por favor")
numb1 = int(input("Número 1: "))
numb2 = int(input("Número 2: "))
mayor = numb1
menor = numb2

if numb1 > numb2:
    if numb1 % numb2 == 0:
        print("El primer número ({}) es mayor que el segundo ({})".format(numb1, numb2))
else:
    if numb2 % numb1 == 0:
        print("El segundo número ({}) es mayor que el primero ({})".format(numb2, numb1))
        mayor = numb2
        menor = numb1

if mayor % menor == 0:
    print("El número Mayor es múltiplo del menor y devuleven un cociente de:", (mayor / menor))
else:
    print("El número Mayor no es múltiplo del menor y devuleven un cociente de:", (mayor / menor), 
          "\ny un resto de:", (mayor % menor))
# Out:
# Introduce dos números enteros positivos por favor
# Número 1: 5
# Número 2: 2
# El número Mayor no es múltiplo del menor y devuleven un cociente de: 2.5
# y un resto de: 1

# %% [markdown]
# Ejercicio 8
#
# Haz que un usuario introduzca una palabra y comprueba si dicha palabra empieza por mayúscula. Devuelve
# por pantalla el resultado en cada caso.

# %%
word = input("Introduce una palabra: ")
if word.istitle():
    print("la palabra {} empieza por mayuscula".format(word))
else:
    print("la palabra {} no empieza por mayuscula".format(word))
# Out:
# Introduce una palabra: Jorge
# la palabra Jorge empieza por mayuscula

# %% [markdown]
# Ejercicio 9
#
# Haz un usuario introduza una letra y comprueba si se trata de una vocal. Si el usuario introduce un string
# de más de un carácter, infórmale de que no se puede procesar el dato, pues debe tener como máximo tamaño
# 1.
# PISTA: Convierte la letra introducida a minúsculas para tener que realizar menos comprobaciones

# %%
one = input("Por favor, introduce una sola vocal en minúscula: ")
if len(one) <= 1:
    one = one.lower()
    if one == "a" or one == "e" or one == "i" or one == "o" or one == "u":
        print("Gracias por introducir la vocal {}".format(one))
    else:
        print("Debes introducir una vocal")
else:
    print("Solo puedes introducir una vocal")
# Out:
# Por favor, introduce una sola vocal: e
# Gracias por introducir la vocal e
