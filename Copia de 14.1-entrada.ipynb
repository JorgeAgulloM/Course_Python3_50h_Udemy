# %% [markdown]
# # La entrada a Isla Verde

# %% [markdown]
# Ya veían a lo lejos su destino, Isla Verde, cuando de pronto una señal emergió del fondo del mar. En ella se leía:
#
# <dl>
# <dd>"Echad el ancla y completad el desafío.</dd>
# <dd>Si osáis intentar seguir adelante</dd>
# <dd>reduciremos a astillas vuestro navío.</dd>
# <dd>El fondo de estas aguas es escalofriante</dd>
# <dd>allí donde estéis se convertirá en un sangrerío</dd>
# <dd>pues seréis alimento para sus habitantes."</dd>
# </dl>
#
# No dudaron ni dos segundos en tirar el ancla. Una vez se aseguraron de que el ancla estaba correctamente enganchada en el fondo de esas terroríficas aguas, la señal se sumergió y al momento volvió a salir otra a la superficie. En la nueva señal podía leerse:
#
# <dl>
# <dd>"La decisión correcta habéis tomado.</dd>
# <dd>Ya va siendo hora de comenzar.</dd>
# <dd>Tendréis que completar todas las pruebas</dd>
# <dd>si a Isla Verde con vida queréis llegar.</dd>
# <dd>Todas estas pruebas son por vuestro bien</dd>
# <dd>pues cada una de ellas os va ayudar</dd>
# <dd>a sobrevivir en la isla que veis en el horizonte.</dd>
# <dd>¡La primera prueba va a empezar!</dd>
# <dd>Cread un módulo y llamadlo isla_verde</dd>
# <dd>donde toda la información vais a apuntar.</dd>
# <dd>En su interior, una clase llamada Tree</dd>
# <dd>es lo primero que vais a crear</dd>
# <dd>y la información que en ella ha de ir</dd>
# <dd>ahora mismo os la voy a mostrar..."</dd>
# </dl>
#
# Ayuda a Pyratilla a crear el módulo llamado `isla_verde` que de momento contenga la clase `Tree` con los siguientes atributos y métodos:
#
# * El atributo `name` que guarda el nombre del árbol
# * El atributo `height` que guarda la altura del árbol
# * El atributo `diameter` que guarda el diámetro del tronco
# * El atributo `talkative` que indica si el árbol habla o no. Por defecto vale `False`
# * El método `.__str__()` que muestre las características del árbol del siguiente modo:
#
# > Si el árbol es parlante: "{name} es un árbol parlante que mide {height}cm de altura y {diameter}cm de diámetro"
#
# > Si el árbol no es parlante: "{name} es un árbol no parlante que mide {height}cm de altura y {diameter}cm de diámetro"
#
#
# * El método `talk()` recibe como parámetro un mensaje, `message`, y si el árbol es parlante, entonces imprime por pantalla el mensaje. De lo contrario, se indica por pantalla que el árbol no es parlante.
# * El método `grow()` recibe por parámetro el crecimiento en altura, `add_height`, y en diámetro, `add_diameter`, y suma las cantidades a la altura y diámetro que tenía originalmente. Por defecto ambos parámetros, `add_height` y `add_diameter`,  deben valer 0.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Scripts py/
# Out:
# /content/drive/MyDrive/Scripts py

# %%
from isla_verde import *

# %%
new_yorch = Tree("Yorch", 160, 60, True)
born_tree(new_yorch)
dead_tree(new_yorch)
for tree in trees:
    print(tree)
# Out:
# Yorch acaba de nacer
# Yorch es un árbol parlante que mide 160cm de altura y 60cm de diámetro
# Descansa en paz, Yorch

# %% [markdown]
# Cuando completaron la primera prueba, alzaron sus cabezas y observaron que la señal anterior había desaparecido. En su lugar, se encontraba otra muy diferente con el siguiente mensaje:
#
# <dl>
# <dd>"Con éxito, la primera prueba habéis completado.</dd>
# <dd>Ahora la segunda debéis resolver</dd>
# <dd>y para llevarla a cabo</dd>
# <dd>esto es lo que tendréis que hacer:</dd>
# <dd>crear la variable del módulo</dd>
# <dd>para de todos los árboles disponer.</dd>
# <dd>Se trata de una lista llamada trees</dd>
# <dd>que los objetos de Tree va a contener.</dd>
# <dd>Pues esa variable os dará</dd>
# <dd>toda la información que necesitáis saber."</dd>
# </dl>
#
# ¡Ayuda a Pyratilla y su tripulación a completar esta segunda prueba! Simplemente hay que crear la variable del módulo llamada `trees`, que sabemos que tiene que ser una lista.

# %% [markdown]
# No tardaron mucho en completar la segunda prueba, pues en comparación a la primera había sido una tarea sencilla. Ante sus ojos vieron aparecer una nueva señal que procedía del fondo del mar. En esta, el mensaje que se leía era:
#
# <dl>
# <dd>"Sencilla era la prueba anterior</dd>
# <dd>y ahora con la tercera debéis seguir.</dd>
# <dd>Esta nueva prueba consiste</dd>
# <dd>en dos métodos sencillos constuir:</dd>
# <dd>uno al que llamaremos born_tree(),</dd>
# <dd>que un objeto de la clase a la lista va a añadir</dd>
# <dd>y el otro será el método dead_tree()</dd>
# <dd>que el objeto pertinente va va a suprimir.</dd>
# <dd>De nuevo, a continuación os detallo</dd>
# <dd>la información que en cada método ha de ir."</dd>
# </dl>
#
# Ayuda a Pyratilla a crear los métodos `born_tree` y `dead_tree` que satisfagan:
#
# * El método `born_tree` recibe por parámetro un objeto, `tree_object`, y se encarga de añadirlo a la lista `trees`.
# * El método `born_tree` muestra por pantalla los mensajes:
# > "{name} acaba de nacer."
#
# > Las características del árbol del método `.__str__()` de la clase `Tree`
#
# * El método `dead_tree` recibe por parámetro un objeto, `tree_object`, y se encarga de eliminarlo de la lista `trees`.
# * El método `dead_tree` muestra por pantalla el siguiente mensaje:
# > "Descansa en paz, {name}"

# %%
arbolato = Tree("Arbolato", 5, 2, True)
born_tree(arbolato)
arboleto = Tree("Arboleto", 4, 1, True)
born_tree(arboleto)
arbolito = Tree("Arbolito", 4, 1.5, True)
born_tree(arbolito)
arboloto = Tree("Arboloto", 4, 0.5)
born_tree(arboloto)
arboluto = Tree("Arboluto", 2, 0.25)
born_tree(arboluto)
# Out:
# Arbolato acaba de nacer
# Arbolato es un árbol parlante que mide 5cm de altura y 2cm de diámetro
# Arboleto acaba de nacer
# Arboleto es un árbol parlante que mide 4cm de altura y 1cm de diámetro
# Arbolito acaba de nacer
# Arbolito es un árbol parlante que mide 4cm de altura y 1.5cm de diámetro
# Arboloto acaba de nacer
# Arboloto es un árbol no parlante que mide 4cm de altura y 0.5cm de diámetro
# Arboluto acaba de nacer
# Arboluto es un árbol no parlante que mide 2cm de altura y 0.25cm de diámetro

# %%
arbolato.grow(5, 2)
arboleto.grow(add_heigth = 3)
arbolito.grow(1, 0.5)
arboloto.grow(add_diameter = 3.5)
arboluto.grow(0.5, 0.75)

# %%
dead_tree(arboluto)
# Out:
# Descansa en paz, Arboluto

# %%
#altura_parantes - diametro_no_parlantes * (diametro_parlantes //  altura_no_parlantes)

heigth_talkatives = 0
diameter_talkatives = 0
heigth_no_talkatives = 0
diameter_no_talkatives = 0

for tree in trees:
    if tree.talkative:
        heigth_talkatives += tree.heigth
        diameter_talkatives += tree.diameter
    else:
        heigth_no_talkatives += tree.heigth
        diameter_no_talkatives += tree.diameter

#total_calc = (heigth_talkatives - diameter_no_talkatives) * (diameter_talkatives // heigth_no_talkatives) a ver si lees ya de una puta vez
total_calc = ((heigth_talkatives - diameter_no_talkatives) * (diameter_talkatives // heigth_no_talkatives) + len(trees) / 2)
total_calc
# Out:
# 20.0
