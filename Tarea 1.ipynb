# %% [markdown]
# Ejercicio 1.
#
# Calcula la división entera de 45 entre 6

# %%
45//6
# Out:
# 7

# %% [markdown]
# Ejercicio 2.
#
# Calcula el resto de la división entera de 45 entre 6

# %%
45 % 6
# Out:
# 3

# %% [markdown]
# Ejercicio 3
#
# Realiza la siguiente operación en Python, donde indica la división entera

# %%
10 + 20 // 7 - 2
# Out:
# 10

# %% [markdown]
# Ejercicio 4
#
# Realiza la siguiente operación en Python

# %%
9 - (25 + 5 - 2 / 7 * 4) / 2 ** 3 #mi respuesta, que es erronea
(9 - (25 + 5 - 2) / (7 * 4)) / 2 ** 3 #respuesta correcta
# Out:
# 1.0

# %% [markdown]
# Ejercicio 5
#
# Realiza la siguiente operación en Python

# %%
2 + 2 ** 3 - 2 * (2 - 2 ** 5) + 2 ** 2 * 2 + 2 / 2 * (2 * 2 - 2 ** 4) + 2 ** 2 #Mi respuesta
(2 + 2 ** 3 - 2 * (2 - 2 ** 5) + 2 ** 2 * 2 + 2) / (2 * (2 * 2 - 2 ** 4) + 2 ** 2) #REspuesta correcta
# Out:
# -4.0

# %% [markdown]
# Ejercicio 6
#
# Realiza la siguiente operación en Python

# %%
6j - (4 + 0j) * 2 #Mi respuesta
6j - (4 + 1j) * 2 #Respuesta correcta
# Out:
# (-8+6j)

# %% [markdown]
# Ejercicio 7
#
# Realiza la siguiente operación en Python

# %%
(1 + 0j / 1 -0j) + (2 / -1 + 0j) #Mi respuesta
(1 + 1j / 1 -1j) + (2 / -1 + 1j) #Respuesta correcta
# Out:
# (-1+1j)

# %% [markdown]
# Ejercicio 8
#
# Realiza la siguiente operación en Python

# %%
(1 + 0j) ** 2 #Mi respuesta
(1 + 1j) ** 2 #Respuesta correcta
# Out:
# 2j

# %% [markdown]
# Ejercicio 9
#
# Realiza la siguiente operación en Python, donde Mod(z) indica módulo del complejo z:

# %%
z = (9 - 3j / -2 - 0j) #Mi respuesta
z = (9 - 3j) / (-2 - 1j) #Respuesta correcta
abs(z)
# Out:
# 4.242640687119285

# %% [markdown]
# Ejercicio 10
#
# ¿Cuás es el argumento del número complejo i?: ESte no se si está correcto, o se busca otra cosa.

# %%
import cmath
cmath.phase(z) #Mi respuesta
cmath.phase(1j) #Respuesta correcta
# Out:
# 1.5707963267948966

# %%
(2 + 1.0) * (int(18.7) / (7 - 5.)) ** 3
# Out:
# 2187.0
