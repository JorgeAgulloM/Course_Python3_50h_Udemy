# %%
import math

a, b, c, n = (20, 10, 5), (4, 8, 16), (30, 60, 120), (2, 4, 6)


for i in range(3):
    print("a = {}, b = {}, c = {}, n = {}.".format(a[i], b[i], c[i], n[i]))
    print(math.log(1, a[i]) == 0)
    print(math.log(a[i], a[i]) == 1)
    print(math.isclose(math.log(b[i] ** n[i], a[i]), n[i] * math.log(b[i], a[i])))
    print(math.isclose(math.log(b[i] ** (1 / n[i]), a[i]),
    (1 / n[i]) * math.log(b[i], a[i])))
    print(math.isclose(math.log(b[i] * c[i], a[i]),
    math.log(b[i], a[i]) + math.log(c[i], a[i])))
    print(math.isclose(math.log(b[i] / c[i], a[i]), math.log(b[i],
    a[i]) - math.log(c[i], a[i])))
    print(math.isclose(math.log(b[i], a[i]), math.log(b[i], c[i]) / math.log(a[i], c[i])))
# Out:
# a = 20, b = 4, c = 30, n = 2.
# True
# True
# True
# True
# True
# True
# True
# a = 10, b = 8, c = 60, n = 4.
# True
# True
# True
# True
# True
# True
# True
# a = 5, b = 16, c = 120, n = 6.
# True
# True
# True
# True
# True
# True
# True

# %%
def degree_to_rad(d):
    return d * 2 * math.pi / 360
def rad_to_degree(r):
    return r * 360 / (2 * math.pi)
    degree_to_rad(540) == math.radians(540)
    rad_to_degree(2 * math.pi) == math.degrees(2 * math.pi)
# EXTRA
def degree_to_rad(d):
    rad = d * 2 * math.pi / 360
    return rad - (rad // (2 * math.pi)) * 2 * math.pi
def rad_to_degree(r):
    deg = r * 360 / (2 * math.pi)
    return deg - (deg // 360) * 360

# %%
alpha = 20
math.sin(alpha) ** 2 + math.cos(alpha) ** 2 == 1
math.tan(alpha) == math.sin(alpha) / math.cos(alpha)
# Out:
# False

# %%
math.isfinite(20 / 0.000000001)
# Out:
# True

# %%
def choose(n, k):
    if (n >= k and k >= 0):
        return math.factorial(n) / (math.factorial(k) * math.factorial(n - k))
    else:
        return "No se puede calcular el número factorial indicado"
    n, k = 20, 15
    choose(n, k) == choose(n, n - k)

# %%
import cmath
cmath.polar(complex(1, -1))
# Out:
# (1.4142135623730951, -0.7853981633974483)

# %%
z = complex(1, -1)
cmath.isclose(cmath.sinh(z), (cmath.exp(z) - cmath.exp(-z)) / 2)
cmath.isclose(cmath.cosh(z), (cmath.exp(z) + cmath.exp(-z)) / 2)
# Out:
# True

# %%
z = complex(1, -1)
cmath.sinh(-z) == -cmath.sinh(z)
cmath.cosh(-z) == cmath.cosh(z)
# Out:
# True

# %%
for i in range(-10, 11):
    print(math.isclose(math.tan(i * math.pi), 0, abs_tol = 0.01))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
a, n, m = (4, 24, 458), (2, 3, 4), (1, 5, 2)
for i in range(3):
    print(math.pow(a[i], m[i]) * math.pow(a[i], n[i]) == math.pow(a[i], m[i] + n[i]))
# Out:
# True
# True
# True
